# %%
# ----------------txt------------- 파일에 대한 전처리 ##############

import os
import re

base_path = "/data/seungmin/dataset/k-12_processed/number_or_english"

def preprocess_text(text):
    # 괄호 표현 처리: (alpha)/(알파) → 알파
    text = re.sub(r"\((.*?)\)/\((.*?)\)", r"\2", text)

    # 말더듬음 및 발화 습관 (예: b/, n/, u/) 제거
    text = re.sub(r"\b[a-zA-Z]+/", "", text)

    # 문장부호(. , ? !)를 제외한 특수문자 제거 (+ / * 등)
    text = re.sub(r"[+/*;:'\"]", "", text)

    # 공백 정리
    text = re.sub(r"\s+", " ", text)

    return text.strip()

# 디렉토리 내 모든 txt 파일 전처리 및 덮어쓰기
for filename in os.listdir(base_path):
    if filename.endswith(".txt"):  # .txt 파일만 처리
        file_path = os.path.join(base_path, filename)
        
        # 기존 파일 읽기
        with open(file_path, "r", encoding="utf-8") as f:
            original_text = f.read()
        
        # 전처리 적용
        processed_text = preprocess_text(original_text)

        # 원본 파일 덮어쓰기
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(processed_text)

        print(f"{filename} 처리 완료 및 덮어쓰기 완료")

print("\n 모든 텍스트 파일 전처리 완료 및 덮어쓰기 완료")

# %%
# ----------------json------------- 파일에 대한 전처리 ##################

import json
import os
import re

# base_path = "/data/seungmin/dataset/k-12_processed/number_or_english"
# base_path = "/data/seungmin/dataset/kr_univ_training_processed/number_or_english"
# base_path = "/data/seungmin/dataset/kr_univ_training_processed/number_and_english"
# base_path = "/data/seungmin/dataset/kr_univ_validation_processed/number_or_english"
base_path = "/data/seungmin/dataset/kr_univ_validation_processed/number_and_english"


def preprocess_text(text):
    # 괄호 표현 처리: (alpha)/(알파) → 알파
    text = re.sub(r"\((.*?)\)/\((.*?)\)", r"\2", text)

    # 말더듬음 및 발화 습관 (예: b/, n/, u/) 제거
    text = re.sub(r"\b[a-zA-Z]+/", "", text)

    # 문장부호(. , ? !)를 제외한 특수문자 제거 (+ / * 등)
    text = re.sub(r"[+/*;:'\"]", "", text)

    # 공백 정리
    text = re.sub(r"\s+", " ", text)

    return text.strip()

# 디렉토리 내 모든 txt 파일 전처리 및 덮어쓰기
for filename in os.listdir(base_path):
    if filename.endswith(".json"):  # .txt 파일만 처리
        file_path = os.path.join(base_path, filename)
        
        # 기존 파일 읽기
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        # "1_text" 필드가 존재하는 경우만 전처리 적용
        if "06_transcription" in data and "1_text" in data["06_transcription"]:
            original_text = data["06_transcription"]["1_text"]
            processed_text = preprocess_text(original_text)

            # 변경된 내용 저장
            data["06_transcription"]["1_text"] = processed_text

            # JSON 덮어쓰기
            with open(file_path, "w", encoding="utf-8") as f:
                json.dump(data, f, ensure_ascii=False, indent=4)

            print(f"{filename} 처리 완료 및 덮어쓰기 완료!")

print("\n 모든 JSON 파일 전처리 완료 및 덮어쓰기 완료")
# Out:
# ✅ arch_C02870_U00282.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00261.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00241.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00219.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00431.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00304.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00592.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00268.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00093.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00300.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00282.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00262.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00112.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00257.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00354.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00469.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00473.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00255.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00084.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00202.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00173.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00383.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00133.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00225.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00225.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00390.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00171.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00189.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00275.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00052.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00030.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00929.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00776.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00162.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00342.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00676.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00449.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00513.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00225.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00172.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00250.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00140.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00205.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00556.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00268.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00095.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00518.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00304.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00274.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00446.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00326.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00120.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00374.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00058.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00658.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00224.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00305.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00090.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00376.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00659.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00048.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00455.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00277.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00090.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00023.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00049.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00147.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00079.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00021.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00133.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00453.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00192.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00014.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00029.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00242.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00344.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00323.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00394.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01001.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00069.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00150.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00191.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00514.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00289.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00038.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00022.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00238.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00441.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00253.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00306.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00259.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00094.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00287.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00163.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00275.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00027.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C13130_U00145.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00442.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00563.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00446.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00269.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00051.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00659.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00021.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00758.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00074.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00053.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00100.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00087.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00119.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00492.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00307.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00515.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00676.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00221.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00370.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00072.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00290.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00261.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00252.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00134.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00348.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00082.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00183.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00295.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00158.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00150.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00187.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00214.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00463.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00496.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01003.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00081.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00063.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00120.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00817.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00450.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00110.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00115.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00238.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C13130_U00129.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00928.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00157.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00313.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00357.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00284.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00346.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00032.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00475.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00485.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00369.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00106.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00036.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00085.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00456.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00153.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00564.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00049.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00296.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00052.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00054.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00458.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01013.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00343.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00135.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00454.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00174.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00471.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00209.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04060_U00471.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00082.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00177.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00195.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00050.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00079.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00216.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00616.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00199.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00465.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00080.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00451.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00597.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00356.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00316.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00290.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00186.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00131.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00140.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00314.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00337.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00176.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00388.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00455.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00069.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00173.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00163.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00294.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00472.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00159.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00075.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00100.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00375.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00075.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00213.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00215.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00174.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00168.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00232.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00709.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00019.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00178.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00188.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C13130_U00237.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00015.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00513.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00033.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00316.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00459.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00456.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00178.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00539.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00238.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00034.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00047.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00884.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00280.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00248.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00293.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00009.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00219.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00438.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00434.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00138.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00509.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00343.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00020.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00132.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00185.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00889.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00468.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00106.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00046.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00114.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00432.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00135.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00821.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00532.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00143.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00412.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00189.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00226.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00410.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00358.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00383.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00329.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00103.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00711.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00311.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00138.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C13130_U00148.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00497.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00579.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00419.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00274.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00044.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00060.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00452.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00930.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00765.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00382.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00151.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00463.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00089.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00609.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00378.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00221.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00431.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00228.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00466.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00009.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00206.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00233.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00201.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00227.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00197.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00057.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00410.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00523.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00268.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00487.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00178.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00481.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00011.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00050.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00705.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00412.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00090.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00535.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00127.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00029.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00508.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00302.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00806.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00024.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00459.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00159.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00150.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00260.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00419.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00133.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00142.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00903.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00934.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00192.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00051.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00442.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00055.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00111.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00207.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00583.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00498.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00312.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00463.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00086.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00116.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00188.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00035.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00369.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00281.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00237.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00002.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00081.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00521.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00268.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00261.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00077.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00069.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00067.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00422.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00211.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00344.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00213.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00394.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00138.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00134.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00271.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00101.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00772.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00149.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00278.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00290.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00049.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00228.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00996.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00260.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00197.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00400.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00017.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00409.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00194.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00132.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00120.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00414.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00215.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00595.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00107.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00114.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00149.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00220.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00221.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00308.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00049.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00080.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00124.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00436.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00038.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00127.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00045.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00212.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00046.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00145.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00191.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01005.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00549.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00551.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00059.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00264.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00088.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00180.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00172.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00100.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00166.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00767.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00141.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00075.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00956.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00388.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00011.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00102.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00267.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00191.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00063.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00343.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00387.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00299.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00777.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00187.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00202.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00238.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00289.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00437.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00226.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00525.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00458.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00456.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00978.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00162.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00457.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00923.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00087.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00501.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00576.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00075.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00062.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00108.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04060_U00256.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00700.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00132.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00705.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00275.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00111.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00175.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00404.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00035.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00187.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00265.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00361.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00267.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00156.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00264.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00137.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00269.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00064.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00670.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00762.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00188.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00298.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00572.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00396.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00460.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00064.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00261.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00955.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00268.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00326.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00671.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00461.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00442.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00213.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00151.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00405.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00694.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00432.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00295.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00399.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00038.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00707.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00537.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00924.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00144.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00426.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00281.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00204.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00462.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00235.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00625.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00282.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00249.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00794.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00142.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00227.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00043.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00354.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00257.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00239.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00045.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00213.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00519.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00139.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00886.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00125.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00233.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00398.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00316.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00829.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00056.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00802.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00227.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00157.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00222.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00084.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00499.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00680.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00601.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00694.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00403.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00327.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00591.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00052.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00706.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01012.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00066.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00929.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00189.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00402.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00232.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00031.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00039.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00028.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00073.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00050.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00185.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00604.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00371.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00512.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00128.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00190.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00229.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00459.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00108.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00091.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00704.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00065.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00125.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00001.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00545.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00664.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00096.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00450.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00414.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00325.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00312.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00258.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00057.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00594.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00145.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00208.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00355.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00429.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00430.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00312.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00287.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00376.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00667.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00443.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00221.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00410.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00130.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00271.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00586.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00414.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00456.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00011.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00674.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00396.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00210.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00099.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00125.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00133.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00052.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00310.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00058.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00045.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00053-1.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00014.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00696.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00169.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00256.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00117.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00350.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00055.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00228.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00226.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00201.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00446.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00534.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00480.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00357.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00174.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00401.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00288.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00411.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00139.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00134.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00056.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00034.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00201.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00247.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00026.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00294.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00509.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00932.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00384.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00699.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00580.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00406.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00165.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00060.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00168.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00154.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00462.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00134.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00477.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00247.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00291.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00153.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00593.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00037.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00577.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00020.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00460.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00017.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00132.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00072.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00086.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00255.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00229.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00047.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00457.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00258.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00223.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00099.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00162.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00096.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00069.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00023.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00520.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00115.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00284.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00357.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00178.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00422.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00317.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00234.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00067.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00460.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00262.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00400.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00346.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00701.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00461.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00014.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00046.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00092.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00530.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00080.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00450.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00459.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00656.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00065.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00097.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00260.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00174.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00286.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00231.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00237.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00034.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00172.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00236.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00196.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00060.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00010.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00634.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00525.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00248.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00317.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00404.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00673.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00025.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00341.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00282.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00405.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00360.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00407.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00443.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00386.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00346.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00079.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00170.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00167.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00059.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00016.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00063.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00517.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00182.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00940.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00277.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00087.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00454.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00280.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00292.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04063_U00466.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00416.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00495.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00415.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00186.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00427.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00234.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00257.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00074.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00353.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00059.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00260.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00297.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00066.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00240.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00024.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00531.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00922.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00352.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00251.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00083.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00044.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00041.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00175.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00094.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00240.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00488.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00235.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00684.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00333.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00321.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00589.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00262.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00263.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00186.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00036.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03964_U00197.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00675.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00307.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00067.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00162.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00291.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00039.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00212.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00058.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00039.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00518.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00510.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01011.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00504.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00598.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00283.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00390.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00405.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00013.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00070.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00161.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00348.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00428.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00107.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00224.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00048.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00154.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00042.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00141.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00020.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00425.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00061.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00429.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00792.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00441.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00020.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00245.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00270.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00228.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00422.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00115.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00031.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00155.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00015.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00386.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00025.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00413.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00249.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00603.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00402.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04157_U00345.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00379.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00061.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00240.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00528.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00113.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00270.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00800.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00503.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00043.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00052.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04060_U00387.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00542.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00281.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00123.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00220.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00340.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00411.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00237.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00114.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00324.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00200.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00260.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00199.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00305.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00444.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00313.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00140.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00296.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00413.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00053.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00452.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00198.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00239.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00132.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00756.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00532.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00597.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00271.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00923.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00005.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00703.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00197.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00196.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00565.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00474.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00697.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00571.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00181.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00092.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00017.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00359.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00099.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00214.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00274.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04060_U00300.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00266.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00034.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00057.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00831.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00070.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02971_U00237.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00567.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00261.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01007.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00092.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00430.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00291.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00246.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00203.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02587_U00269.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00203.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00080.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U01000.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00306.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00489.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00177.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00108.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00149.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00906.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00340.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00110.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00271.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00881.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03981_U00128.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04004_U00091.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04050_U00217.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00216.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00280.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00386.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00002.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00263.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00278.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00151.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00101.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00184.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C08330_U00262.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00272.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03030_U00024.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02861_U00241.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00263.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02841_U00105.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00370.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00999.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00130.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02633_U00006.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00473.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00404.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00883.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00199.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00402.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00658.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06771_U00056.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00425.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00259.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02251_U00403.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C12601_U00804.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06620_U00003.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00143.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02369_U00019.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03964_U00191.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02870_U00707.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02799_U00266.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02709_U00252.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C02193_U00239.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C13130_U00124.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C06613_U00153.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C04006_U00113.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C03974_U00196.json 처리 완료 및 덮어쓰기 완료!
# ✅ arch_C27601_U00233.json 처리 완료 및 덮어쓰기 완료!
#
# 🚀 모든 JSON 파일 전처리 완료 및 덮어쓰기 완료! ✅
