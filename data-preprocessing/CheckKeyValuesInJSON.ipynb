# %%
# JSON 내 “06_transcription” 키 값 목록 확인 코드

import os
import json
from collections import defaultdict

# JSON 데이터 경로
data_dirs = [
    "/data/seungmin/training/labels/eng/arch/",
    "/data/seungmin/training/labels/eng/comp/",
    "/data/seungmin/training/labels/eng/elec/"
    "/data/seungmin/validation/labels/eng/arch/"
    "/data/seungmin/validation/labels/eng/comp/"
    "/data/seungmin/validation/labels/eng/elec/"
]

# "06_transcription" 내부 키 목록 저장
transcription_keys = defaultdict(int)

# JSON 파일 목록 가져오기
json_files = []
for data_dir in data_dirs:
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".json") and not file.startswith("._"):
                json_files.append(os.path.join(root, file))

# JSON 파일 검사
for json_file in json_files:
    try:
        with open(json_file, "r", encoding="utf-8") as f:
            data = json.load(f)

        # "06_transcription" 키 값 확인
        if "06_transcription" in data:
            for key in data["06_transcription"].keys():
                transcription_keys[key] += 1

    except Exception as e:
        print(f"@@@@@@ 오류 발생: {json_file} (오류: {e})")

# 결과 출력
print("'06_transcription' 내부 키 개수:")
for key, count in transcription_keys.items():
    print(f"- {key}: {count}개 파일에 존재")
# Out:
# 🔍 '06_transcription' 내부 키 개수:
# - 1_text: 182304개 파일에 존재
# - 2_entity: 10936개 파일에 존재

# %%
# “2_entity” 예시 데이터 확인 코드

import os
import json

# JSON 데이터 경로
data_dirs = [
    "/data/seungmin/training/labels/eng/arch/",
    "/data/seungmin/training/labels/eng/comp/",
    "/data/seungmin/training/labels/eng/elec/"
    "/data/seungmin/validation/labels/eng/arch/"
    "/data/seungmin/validation/labels/eng/comp/"
    "/data/seungmin/validation/labels/eng/elec/"
]

# "2_entity" 포함된 샘플 확인
entity_samples = []

# JSON 파일 검사
for data_dir in data_dirs:
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".json") and not file.startswith("._"):
                json_path = os.path.join(root, file)
                
                try:
                    with open(json_path, "r", encoding="utf-8") as f:
                        data = json.load(f)

                    # "06_transcription" 안에 "2_entity"가 포함된 경우 확인
                    if "06_transcription" in data and "2_entity" in data["06_transcription"]:
                        entity_samples.append(data["06_transcription"]["2_entity"])

                        # 5개만 확인하면 충분하므로 break
                        if len(entity_samples) >= 5:
                            break

                except Exception as e:
                    print(f"@@@@@@@2 오류 발생: {json_path} (오류: {e})")

# 결과 출력
print(" '2_entity' 샘플 데이터:")
for i, sample in enumerate(entity_samples, 1):
    print(f"[샘플 {i}] {sample}")
# Out:
# 🔍 '2_entity' 샘플 데이터:
# [샘플 1] [{'1_word': 'Thomas', '2_desc': '독일의 표현주의 작가인 &lt;FL&gt;요스트&lt;/FL&gt;(Johst, H.)의 희곡. 영국 식민지의 자유 해방을 외치는 고수(鼓手)의 생애를 극적으로 묘사한 작품이다. ⇒규범 표기는 미확정이다.'}]
# [샘플 2] [{'1_word': '정압', '2_desc': '유체의 흐름과 평행인 면에 수직으로 작용하는 압력.'}]
# [샘플 3] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}]
# [샘플 4] [{'1_word': '정압', '2_desc': '유체의 흐름과 평행인 면에 수직으로 작용하는 압력.'}, {'1_word': '동압', '2_desc': '흐르고 있는 물체가 나타내는 총압 가운데 흐름의 속도에 관계되는 부분의 압력. 흐르는 유체의 밀도를 p, 속도를 v로 할 때, 그 크기는 1/2pv<sup>2</sup>이다.'}]
# [샘플 5] [{'1_word': '동압', '2_desc': '흐르고 있는 물체가 나타내는 총압 가운데 흐름의 속도에 관계되는 부분의 압력. 흐르는 유체의 밀도를 p, 속도를 v로 할 때, 그 크기는 1/2pv<sup>2</sup>이다.'}, {'1_word': '정압', '2_desc': '유체의 흐름과 평행인 면에 수직으로 작용하는 압력.'}]
# [샘플 6] [{'1_word': '포괄 수가제', '2_desc': '같은 종류의 질병에 대해서, 환자에게 제공되는 서비스의 양이나 질에 관계없이 똑같은 치료비를 부과하도록 하는 제도.'}]
# [샘플 7] [{'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 8] [{'1_word': '습도', '2_desc': '공기 가운데 수증기가 들어 있는 정도. 공기가 포함할 수 있는 최대 수증기의 양은 온도에 따라 다른데, 그 포화 수증기량에 대한 비율을 상대 습도라 하고, 일정 부피 속에 포함된 수증기량을 그램 단위로 나타낸 수를 절대 습도라 한다.'}]
# [샘플 9] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 10] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 11] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 12] [{'1_word': '라디안', '2_desc': '원둘레 위에서 반지름의 길이와 같은 길이를 갖는 호에 대응하는 중심각의 크기. 1라디안은 약 57도 17분 44.8초이다. 기호는 rad.'}]
# [샘플 13] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}, {'1_word': '전역 변수', '2_desc': '파일 내의 모든 함수에서 유효한 변수.'}]
# [샘플 14] [{'1_word': '바깥지름', '2_desc': '관(管) 따위의 바깥쪽에서 잰 지름.'}, {'1_word': '안지름', '2_desc': '관(管) 따위의 안쪽에서 잰 지름.'}]
# [샘플 15] [{'1_word': '모집단', '2_desc': '통계적인 관찰의 대상이 되는 집단 전체. 측정이나 조사를 하기 위하여 표본을 뽑아내는 바탕이 된다.'}]
# [샘플 16] [{'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}]
# [샘플 17] [{'1_word': '세분 시장', '2_desc': '특정한 마케팅 자극에 대하여 유사한 자극을 보이는 독립적인 집단들로 나누어진 시장. 전체 시장을 내부적으로 유사하고 외부적으로 상이한 하위 집단으로 분리할 때 도출된다.'}]
# [샘플 18] [{'1_word': '실수', '2_desc': '유리수와 무리수를 통틀어 이르는 말. 사칙 연산이 가능하고, 양수ㆍ음수ㆍ0의 구분이 있으며, 크기의 차례가 있다.'}, {'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 19] [{'1_word': '비투비', '2_desc': '기업과 기업이 전자 문서로 거래하는 일. 기업과 기업 사이의 거래에서 발생하는 주문, 공급, 생산, 판매, 물류 따위의 정보를 컴퓨터 통신망을 이용하여 처리하는 것을 이른다.'}]
# [샘플 20] [{'1_word': '추력', '2_desc': '물체를 운동 방향으로 밀어붙이는 힘. 프로펠러의 회전 또는 분사 가스의 반동에 의하여 생기는 추진력을 이른다.'}]
# [샘플 21] [{'1_word': '페이로드', '2_desc': '항공기가 수송할 수 있는, 요금을 징수하는 화물.'}]
# [샘플 22] [{'1_word': '불상', '2_desc': '부처의 형상을 표현한 상. 나무ㆍ돌ㆍ쇠ㆍ흙 따위로 만든, 부처의 소상(塑像)이나 화상(畫像)을 통틀어 이르는 말이다.'}]
# [샘플 23] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 24] [{'1_word': '구속 조건', '2_desc': '제어계에서 제어 신호, 제어 법칙 및 상태 변수에 주어지는 일정한 제약 조건.'}]
# [샘플 25] [{'1_word': '에어사이드', '2_desc': '공항의 출국 게이트 안쪽 편. 부속 건물 가운데에서 승객과 공항 관계자만 접근이 허가된 공간이다.'}]
# [샘플 26] [{'1_word': '추력', '2_desc': '물체를 운동 방향으로 밀어붙이는 힘. 프로펠러의 회전 또는 분사 가스의 반동에 의하여 생기는 추진력을 이른다.'}]
# [샘플 27] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 28] [{'1_word': '페이로드', '2_desc': '항공기가 수송할 수 있는, 요금을 징수하는 화물.'}]
# [샘플 29] [{'1_word': '건구 온도', '2_desc': '건습구 온도계에서 건구 온도계로 계측한 공기의 온도. 공기 중의 수증기 함량에 영향을 받지 않는 온도로, 일반적인 기온을 말한다.'}, {'1_word': '습구 온도', '2_desc': '습구 온도계에 나타난 온도. 보통의 건구 온도계로 측정한 온도보다 낮다.'}]
# [샘플 30] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 31] [{'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 32] [{'1_word': '대류', '2_desc': '기체나 액체에서, 물질이 이동함으로써 열이 전달되는 현상. 기체나 액체가 부분적으로 가열되면 가열된 부분이 팽창하면서 밀도가 작아져 위로 올라가고, 위에 있던 밀도가 큰 부분은 내려오게 되는데, 이런 과정이 되풀이되면서 기체나 액체의 전체가 고르게 가열된다.'}]
# [샘플 33] [{'1_word': '유에이엠', '2_desc': '도심의 하늘을 교통로로 하여 이루어지는 차세대 운송 체계. 도심의 교통 혼잡을 줄이기 위한 것으로, 수직 이착륙ㆍ자동 비행 등의 기술이 적용된 개인용 항공기가 교통수단으로 이용된다.'}]
# [샘플 34] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 35] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 36] [{'1_word': '허브 공항', '2_desc': '항공사들이 어느 특정 공항을 중심으로 승객이나 화물을 집결하고 분산하는 방사형의 운송 구조를 형성할 때, 그 중심지 역할을 하는 공항.'}]
# [샘플 37] [{'1_word': '유효 온도', '2_desc': '사람이 느끼는 온도. 사람이 느끼는 추위와 더위의 감각을 기온ㆍ습도ㆍ풍속의 세 요소의 조합으로 나타낸 것이다.'}]
# [샘플 38] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 39] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 40] [{'1_word': '페이로드', '2_desc': '항공기가 수송할 수 있는, 요금을 징수하는 화물.'}]
# [샘플 41] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 42] [{'1_word': '상대 습도', '2_desc': '일정 부피의 공기 속에 실제로 포함되어 있는 수증기 양과 포함할 수 있는 최대한의 수증기 양과의 비율. 보통 단순히 습도라고 하며, 건습계로 잰다.'}, {'1_word': '노점 온도', '2_desc': '수증기가 물이 되기 전 이슬이 맺히는 정도로 냉각될 때의 최저 온도.'}]
# [샘플 43] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}]
# [샘플 44] [{'1_word': '회전익', '2_desc': '중심축을 중심으로 회전하여 양력이 생기는 날개. 헬리콥터의 날개 따위를 이른다.'}]
# [샘플 45] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 46] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 47] [{'1_word': '추력', '2_desc': '물체를 운동 방향으로 밀어붙이는 힘. 프로펠러의 회전 또는 분사 가스의 반동에 의하여 생기는 추진력을 이른다.'}]
# [샘플 48] [{'1_word': '드론', '2_desc': '자율 항법 장치에 의하여 자동 조종되거나 무선 전파를 이용하여 원격 조종되는 무인 비행 물체.'}]
# [샘플 49] [{'1_word': '비동기', '2_desc': '공급한 에너지의 크기에 따라 회전 속도가 다른 것.'}]
# [샘플 50] [{'1_word': '에어사이드', '2_desc': '공항의 출국 게이트 안쪽 편. 부속 건물 가운데에서 승객과 공항 관계자만 접근이 허가된 공간이다.'}]
# [샘플 51] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 52] [{'1_word': '동압', '2_desc': '흐르고 있는 물체가 나타내는 총압 가운데 흐름의 속도에 관계되는 부분의 압력. 흐르는 유체의 밀도를 p, 속도를 v로 할 때, 그 크기는 1/2pv<sup>2</sup>이다.'}]
# [샘플 53] [{'1_word': '유형재', '2_desc': '일정한 형태를 가지고 있는 재산. 화폐, 동산, 부동산, 상품 따위를 이른다.'}]
# [샘플 54] [{'1_word': '실링', '2_desc': '항공 기상 용어의 하나. 운량(雲量)이 6 이상인 운층(雲層)의 밑면과 지면 사이의 거리. 또는 비행기로부터 지상이 보이는 최대 고도를 이른다.'}]
# [샘플 55] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 56] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}]
# [샘플 57] [{'1_word': '행렬', '2_desc': '여러 숫자나 문자를 정사각형 또는 직사각형으로 배열한 것. 배열한 숫자나 문자를 그 행렬의 성분 또는 원소라고 하고, 가로로 배열된 원소를 행, 세로로 배열된 원소를 열이라고 한다.'}]
# [샘플 58] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}, {'1_word': '항력', '2_desc': '어떤 물체가 유체 속을 운동할 때에 운동 방향과는 반대쪽으로 물체에 미치는 유체의 저항력. 항공 역학에 응용한다.'}]
# [샘플 59] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}, {'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 60] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}]
# [샘플 61] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 62] [{'1_word': '회전익', '2_desc': '중심축을 중심으로 회전하여 양력이 생기는 날개. 헬리콥터의 날개 따위를 이른다.'}]
# [샘플 63] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}]
# [샘플 64] [{'1_word': '불상', '2_desc': '부처의 형상을 표현한 상. 나무ㆍ돌ㆍ쇠ㆍ흙 따위로 만든, 부처의 소상(塑像)이나 화상(畫像)을 통틀어 이르는 말이다.'}]
# [샘플 65] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 66] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 67] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 68] [{'1_word': '모집단', '2_desc': '통계적인 관찰의 대상이 되는 집단 전체. 측정이나 조사를 하기 위하여 표본을 뽑아내는 바탕이 된다.'}]
# [샘플 69] [{'1_word': '헤딩', '2_desc': '기수(機首)가 향하고 있는 실제 방향. 일반적으로 북쪽을 기준으로 하여 항공기의 세로축이 가리키는 방향을 이른다.'}]
# [샘플 70] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 71] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}, {'1_word': '피아이비', '2_desc': '비행에 앞서 작성하는 항공 고시보 정보를 포함하여 게시하는 일.'}]
# [샘플 72] [{'1_word': '치근단', '2_desc': '이뿌리의 끝. 교합면에서 가장 먼 부분이다.'}, {'1_word': '치근', '2_desc': '잇몸 속에 들어 있는 이의 뿌리.'}]
# [샘플 73] [{'1_word': '마케팅 믹스', '2_desc': '기업이 계획한 마케팅 목표를 이루기 위하여 여러 가지 전략, 전술을 종합적으로 실시하는 일. 제품, 유통 경로, 판매 가격, 판매 촉진의 네 요소를 합리적으로 결합하는 것을 이른다.'}]
# [샘플 74] [{'1_word': '마케팅 믹스', '2_desc': '기업이 계획한 마케팅 목표를 이루기 위하여 여러 가지 전략, 전술을 종합적으로 실시하는 일. 제품, 유통 경로, 판매 가격, 판매 촉진의 네 요소를 합리적으로 결합하는 것을 이른다.'}]
# [샘플 75] [{'1_word': '페이로드', '2_desc': '항공기가 수송할 수 있는, 요금을 징수하는 화물.'}]
# [샘플 76] [{'1_word': '리셋', '2_desc': '기억 장치나 계수기, 레지스터 따위를 영(零)의 상태로 되돌리는 일.'}]
# [샘플 77] [{'1_word': '음속', '2_desc': '소리가 매질(媒質)을 통하여 전파되는 속도. 공기 중의 음속은 0℃, 1기압일 때 초당 331.5미터인데, 온도가 1℃ 오를 때마다 초당 약 0.6미터씩 증가하며 물속에서는 초당 약 1,500미터씩 증가한다.'}]
# [샘플 78] [{'1_word': '행렬', '2_desc': '여러 숫자나 문자를 정사각형 또는 직사각형으로 배열한 것. 배열한 숫자나 문자를 그 행렬의 성분 또는 원소라고 하고, 가로로 배열된 원소를 행, 세로로 배열된 원소를 열이라고 한다.'}]
# [샘플 79] [{'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 80] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 81] [{'1_word': '시장 세분화', '2_desc': '나이, 직업, 지역, 기호 따위에 따라 시장을 자세하게 나누고 소비자에게 알맞게 팔 계획을 세우는 일.'}]
# [샘플 82] [{'1_word': '아이엘에스', '2_desc': '날씨가 좋지 않아 비행장이 안 보일 경우에, 항공기를 공항에 안전하게 착륙시키기 위하여 지상에서 활주로의 방향과 진입 각을 나타내는 전파를 보내어 착륙하도록 하는 방법.'}]
# [샘플 83] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 84] [{'1_word': '비동기', '2_desc': '공급한 에너지의 크기에 따라 회전 속도가 다른 것.'}]
# [샘플 85] [{'1_word': '제약 조건', '2_desc': '계획 문제에 수반되는 각종 조건. 수리 계획법에서는 벡터 변수가 포함되어 있는 영역을 기술하며, 보통 몇 개의 부등식이나 등식 또는 변수가 취할 수 있는 값의 조합으로 기술된다.'}]
# [샘플 86] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 87] [{'1_word': '투각', '2_desc': '조각에서, 묘사할 대상의 윤곽만을 남겨 놓고 나머지 부분은 파서 구멍이 나도록 만들거나, 윤곽만을 파서 구멍이 나도록 만듦. 또는 그런 기법.'}]
# [샘플 88] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 89] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 90] [{'1_word': '오마주', '2_desc': '영화를 촬영할 때, 다른 감독이나 작가에 대한 존경의 표시로 그 감독이나 작가가 만든 영화의 대사나 장면을 인용하는 일. 프랑스어로 ‘존경’, ‘경의’를 뜻한다.'}]
# [샘플 91] [{'1_word': '어레이', '2_desc': '컴퓨터 표의 형태로 저장된 값들의 모음. 하나의 어레이는 하나 또는 그 이상의 차원을 가질 수 있다.'}]
# [샘플 92] [{'1_word': '헤딩', '2_desc': '기수(機首)가 향하고 있는 실제 방향. 일반적으로 북쪽을 기준으로 하여 항공기의 세로축이 가리키는 방향을 이른다.'}]
# [샘플 93] [{'1_word': '로터', '2_desc': '발전기, 전동기, 터빈, 수차 따위의 회전 기계에서 회전하는 부분을 통틀어 이르는 말.'}]
# [샘플 94] [{'1_word': '잠열', '2_desc': '고체가 액체로, 액체가 기체로 변할 때, 온도 상승의 효과를 나타내지 않고 단순히 물질의 상태를 바꾸는 데 쓰는 열. 곧 액화열과 기화열을 가리킨다.'}]
# [샘플 95] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 96] [{'1_word': '디버깅', '2_desc': '만든 프로그램들이 정확한가를 조사하는 과정. 프로그램 순서도를 살피는 검사, 컴파일러를 사용한 검사, 실제 데이터를 사용한 검사의 세 단계로 이루어진다.'}]
# [샘플 97] [{'1_word': '투각', '2_desc': '조각에서, 묘사할 대상의 윤곽만을 남겨 놓고 나머지 부분은 파서 구멍이 나도록 만들거나, 윤곽만을 파서 구멍이 나도록 만듦. 또는 그런 기법.'}]
# [샘플 98] [{'1_word': '비투비', '2_desc': '기업과 기업이 전자 문서로 거래하는 일. 기업과 기업 사이의 거래에서 발생하는 주문, 공급, 생산, 판매, 물류 따위의 정보를 컴퓨터 통신망을 이용하여 처리하는 것을 이른다.'}]
# [샘플 99] [{'1_word': '대류', '2_desc': '기체나 액체에서, 물질이 이동함으로써 열이 전달되는 현상. 기체나 액체가 부분적으로 가열되면 가열된 부분이 팽창하면서 밀도가 작아져 위로 올라가고, 위에 있던 밀도가 큰 부분은 내려오게 되는데, 이런 과정이 되풀이되면서 기체나 액체의 전체가 고르게 가열된다.'}]
# [샘플 100] [{'1_word': '허브 공항', '2_desc': '항공사들이 어느 특정 공항을 중심으로 승객이나 화물을 집결하고 분산하는 방사형의 운송 구조를 형성할 때, 그 중심지 역할을 하는 공항.'}]
# [샘플 101] [{'1_word': '항행 안전시설', '2_desc': '항공기가 항행하는 데 이용하는 항행 보조 시설을 통틀어 이르는 말. 항공기에 탑재되거나 지상에 설치된 시각적 또는 전자적 장치로, 항행 중인 항공기의 항로와 관련된 정보나 위치에 관한 데이터를 제공한다.'}]
# [샘플 102] [{'1_word': '연돌 효과', '2_desc': '수직으로 세운 벽의 안과 밖의 온도 차이로 발생하는 공기 이동 현상. 벽의 안쪽이 바깥쪽보다 온도가 높고 밀도가 낮을 때 연기와 열이 상층부로 움직인다.'}]
# [샘플 103] [{'1_word': '트랜스듀서', '2_desc': '한 형태의 전기 에너지를 다른 형태의 전기 에너지로 바꾸는 장치. 교류 전력을 직류 전력으로 변환하거나 직류 전력을 교류 전력으로 변환하는 것, 또는 어떤 주파수에서 다른 주파수로 변환하는 것 따위를 이른다. 교류를 직류로 바꾸는 변환기, 라디오 수신기의 주파수 변환기, 텔레비전의 채널 변환기 따위가 있다. ⇒규범 표기는 미확정이다.'}]
# [샘플 104] [{'1_word': '매크로', '2_desc': '여러 개의 명령을 묶어 하나의 명령으로 만든 것. 여러 개의 명령을 수행하는 반복적인 작업에서 하나의 매크로 명령만으로 효과적인 작업을 수행할 수 있다.'}]
# [샘플 105] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}]
# [샘플 106] [{'1_word': '노점 온도', '2_desc': '수증기가 물이 되기 전 이슬이 맺히는 정도로 냉각될 때의 최저 온도.'}]
# [샘플 107] [{'1_word': '드론', '2_desc': '자율 항법 장치에 의하여 자동 조종되거나 무선 전파를 이용하여 원격 조종되는 무인 비행 물체.'}]
# [샘플 108] [{'1_word': '에일러론', '2_desc': '비행기 날개의 뒷전 끝단에 장착된 주 조종 면. 조종 휠의 회전 또는 조종간의 좌우 운동에 의해서 작동된다. 이 면의 각도 변경으로 항공기는 세로축을 중심으로 운동하게 된다. ⇒규범 표기는 미확정이다.'}]
# [샘플 109] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 110] [{'1_word': '문화재 보호법', '2_desc': '문화재를 보호하여 활용함으로써 국민의 문화적 향상을 도모하고 인류 문화의 발전에 기여함을 목적으로 제정한 법률.'}]
# [샘플 111] [{'1_word': '아이엘에스', '2_desc': '날씨가 좋지 않아 비행장이 안 보일 경우에, 항공기를 공항에 안전하게 착륙시키기 위하여 지상에서 활주로의 방향과 진입 각을 나타내는 전파를 보내어 착륙하도록 하는 방법.'}, {'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 112] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 113] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 114] [{'1_word': '브이에이치에프', '2_desc': '파장이 아주 짧은 전자기파. 진동수 30~300MHz, 파장 1~10미터의 전파로 전리층에서 반사되지 않고 곧게 진행하는 성질이 강하므로 가까운 거리의 통신이나 방송에 쓰인다.'}]
# [샘플 115] [{'1_word': '리셋', '2_desc': '기억 장치나 계수기, 레지스터 따위를 영(零)의 상태로 되돌리는 일.'}]
# [샘플 116] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}, {'1_word': '항력', '2_desc': '어떤 물체가 유체 속을 운동할 때에 운동 방향과는 반대쪽으로 물체에 미치는 유체의 저항력. 항공 역학에 응용한다.'}]
# [샘플 117] [{'1_word': '치수', '2_desc': '치강 속에 가득 차 있는 부드럽고 연한 조직. 혈관과 신경이 많이 분포되어 있어 감각이 예민하다.'}]
# [샘플 118] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 119] [{'1_word': '문자열', '2_desc': '데이터로 다루는 일련의 문자. 숫자를 포함하는 것이어도 계산하는 숫자로서가 아니라 코드의 일부로 쓰는 것이면 문자열이라 할 수 있다.'}]
# [샘플 120] [{'1_word': '쌍극자', '2_desc': '작은 자석 따위와 같이 양과 음의 전기 또는 자극(磁極)이 서로 마주 대하고 있는 물체. 양전기와 음전기, 자석의 남극과 북극 따위가 있다.'}]
# [샘플 121] [{'1_word': '와트', '2_desc': '일률의 국제단위. 주로 전력의 단위로 쓴다. 1와트는 1초에 1줄(joule)의 일을 하는 것으로, 1볼트의 전압으로 1암페어의 전류가 흐를 때의 전력의 크기이다. 영국의 기계 기술자 와트의 이름에서 유래한다. 기호는 W.'}]
# [샘플 122] [{'1_word': '온도 구배', '2_desc': '등온면의 법선 방향에 있는 등온면 사이의 거리에 대한 온도 변화의 값.'}]
# [샘플 123] [{'1_word': '페이로드', '2_desc': '항공기가 수송할 수 있는, 요금을 징수하는 화물.'}]
# [샘플 124] [{'1_word': '우식증', '2_desc': '입안의 유산균이 이의 석회질을 상하게 하여 충치가 되는 증상.'}]
# [샘플 125] [{'1_word': '로터', '2_desc': '발전기, 전동기, 터빈, 수차 따위의 회전 기계에서 회전하는 부분을 통틀어 이르는 말.'}]
# [샘플 126] [{'1_word': '조건문', '2_desc': '루틴 내에서 주어진 어떤 조건이 만족되었을 때만 수행되는 문장.'}]
# [샘플 127] [{'1_word': '아이엘에스', '2_desc': '날씨가 좋지 않아 비행장이 안 보일 경우에, 항공기를 공항에 안전하게 착륙시키기 위하여 지상에서 활주로의 방향과 진입 각을 나타내는 전파를 보내어 착륙하도록 하는 방법.'}]
# [샘플 128] [{'1_word': '상아질', '2_desc': '척추동물의 치아를 이루는 노란빛을 띤 흰색의 단단한 물질. 내부에 치수강이 있으며, 치관(齒冠)은 에나멜질, 이촉은 시멘트질로 덮여 있고 뼈와 비슷한 성질이나 뼈보다 단단하다.'}]
# [샘플 129] [{'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 130] [{'1_word': '어레이', '2_desc': '컴퓨터 표의 형태로 저장된 값들의 모음. 하나의 어레이는 하나 또는 그 이상의 차원을 가질 수 있다.'}]
# [샘플 131] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}]
# [샘플 132] [{'1_word': '허브 공항', '2_desc': '항공사들이 어느 특정 공항을 중심으로 승객이나 화물을 집결하고 분산하는 방사형의 운송 구조를 형성할 때, 그 중심지 역할을 하는 공항.'}]
# [샘플 133] [{'1_word': '아이엘에스', '2_desc': '날씨가 좋지 않아 비행장이 안 보일 경우에, 항공기를 공항에 안전하게 착륙시키기 위하여 지상에서 활주로의 방향과 진입 각을 나타내는 전파를 보내어 착륙하도록 하는 방법.'}, {'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 134] [{'1_word': '마케팅 믹스', '2_desc': '기업이 계획한 마케팅 목표를 이루기 위하여 여러 가지 전략, 전술을 종합적으로 실시하는 일. 제품, 유통 경로, 판매 가격, 판매 촉진의 네 요소를 합리적으로 결합하는 것을 이른다.'}]
# [샘플 135] [{'1_word': '랜딩', '2_desc': '비행기 따위의 착륙.'}]
# [샘플 136] [{'1_word': '헤더 파일', '2_desc': '일련의 데이터 집단의 서두에 있는 항목으로서 그다음에 계속되는 데이터에 관한 각종 정보를 기록하고 있는 것. 자기 테이프의 경우 그 테이프의 선두에 붙어 있고, 그 테이프에 수록되어 있는 데이터의 특정이나 장치 및 시스템에 관한 정보 따위가 기록되어 있으며, 자기 테이프에 기록하거나 읽기 전에 정확한 테이프 릴을 옳게 처리하는가를 사전에 체크하기 위해 사용된다.'}]
# [샘플 137] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 138] [{'1_word': '허브 공항', '2_desc': '항공사들이 어느 특정 공항을 중심으로 승객이나 화물을 집결하고 분산하는 방사형의 운송 구조를 형성할 때, 그 중심지 역할을 하는 공항.'}]
# [샘플 139] [{'1_word': '아말감', '2_desc': '수은과 다른 금속과의 합금. 수은의 양이 많으면 액체 상태가 되나, 대부분이 고체 상태이다. 수은은 백금, 철, 니켈, 망가니즈, 코발트 따위의 녹는점이 높은 몇 가지의 금속을 제외하고 여러 실용 금속과 서로 녹아 아말감이 된다. 금과 은의 야금, 거울의 반사면, 치과용 충전재 따위로 쓴다.'}]
# [샘플 140] [{'1_word': '습도', '2_desc': '공기 가운데 수증기가 들어 있는 정도. 공기가 포함할 수 있는 최대 수증기의 양은 온도에 따라 다른데, 그 포화 수증기량에 대한 비율을 상대 습도라 하고, 일정 부피 속에 포함된 수증기량을 그램 단위로 나타낸 수를 절대 습도라 한다.'}, {'1_word': '수분 함유량', '2_desc': '흙이나 오물 또는 체로 밭아 낸 무거리 따위의 부피 가운데 포함된 수분의 양. 총량에 대한 수분의 중량을 백분율로 나타낸다.'}, {'1_word': '습도계', '2_desc': '공기 속의 습도를 재는 계기. 습기의 차이로 생기는 머리카락의 신축을 이용한 모발 습도계, 노점(露點)을 재는 노점 습도계 따위가 있다.'}, {'1_word': '상대 습도', '2_desc': '일정 부피의 공기 속에 실제로 포함되어 있는 수증기 양과 포함할 수 있는 최대한의 수증기 양과의 비율. 보통 단순히 습도라고 하며, 건습계로 잰다.'}]
# [샘플 141] [{'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 142] [{'1_word': '비투비', '2_desc': '기업과 기업이 전자 문서로 거래하는 일. 기업과 기업 사이의 거래에서 발생하는 주문, 공급, 생산, 판매, 물류 따위의 정보를 컴퓨터 통신망을 이용하여 처리하는 것을 이른다.'}]
# [샘플 143] [{'1_word': '무인 항공기', '2_desc': '사람이 없이 자동 또는 원격 조종 장치로 운항하는 항공기.'}]
# [샘플 144] [{'1_word': '열전도율', '2_desc': '물체 속을 열이 전도하는 정도를 나타낸 수치. 열전도에서, 열의 흐름에 수직인 단위 면적을 지나서 단위 시간에 흐르는 열량을 단위 길이당 온도의 차이로 나눈 값이다.'}]
# [샘플 145] [{'1_word': '리셋', '2_desc': '기억 장치나 계수기, 레지스터 따위를 영(零)의 상태로 되돌리는 일.'}]
# [샘플 146] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}]
# [샘플 147] [{'1_word': '우식증', '2_desc': '입안의 유산균이 이의 석회질을 상하게 하여 충치가 되는 증상.'}]
# [샘플 148] [{'1_word': '아이아타', '2_desc': '1944년 시카고에서 채택되어, 1945년 발효된 국제 항공 협정. 국가 간의 상공 통과의 자유, 기술 착륙의 자유 따위를 인정하였다. 백여 국이 가입하였으며 우리나라는 1960년에 가입하였다.'}]
# [샘플 149] [{'1_word': '마케팅 믹스', '2_desc': '기업이 계획한 마케팅 목표를 이루기 위하여 여러 가지 전략, 전술을 종합적으로 실시하는 일. 제품, 유통 경로, 판매 가격, 판매 촉진의 네 요소를 합리적으로 결합하는 것을 이른다.'}]
# [샘플 150] [{'1_word': '라이프 스타일', '2_desc': '생활 구조, 생활 의식, 생활 행동의 세 가지 요소가 결합된 생활 체계. 마케팅이나 소비자 행동 연구의 주요 분석 과제이다.'}]
# [샘플 151] [{'1_word': '양력', '2_desc': '유체 속을 운동하는 물체에 운동 방향과 수직 방향으로 작용하는 힘. 비행기는 날개에서 생기는 이 힘에 의하여 공중을 날 수 있다.'}]
# [샘플 152] [{'1_word': '계기 비행', '2_desc': '어둠이나 안개 따위로 앞이 보이지 아니하는 항로를 계기에 의존하여 비행하는 일.'}]
# [샘플 153] [{'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 154] [{'1_word': '로터', '2_desc': '발전기, 전동기, 터빈, 수차 따위의 회전 기계에서 회전하는 부분을 통틀어 이르는 말.'}]
# [샘플 155] [{'1_word': '에스큐엘', '2_desc': '데이터베이스에서 정보를 얻거나 갱신하기 위해 표준 대화식으로 구성된 프로그래밍 언어. 관계형 데이터베이스 관리 시스템에서의 자료 검색과 관리, 데이터베이스 관리 시스템에서 데이터 구조와 표현 기술을 수용하는 데이터베이스 스키마 파일의 생성과 수정, 데이터베이스 객체의 접근 조정 관리를 위해 고안되었다. 대다수의 데이터베이스 관련 프로그램들이 이 언어를 표준으로 채택하고 있다.'}]
# [샘플 156] [{'1_word': '퍼셉트론', '2_desc': '시각과 뇌의 기능을 모델화한 학습 기계. 학습 기능과 지적 동작 기능을 가진 패턴 인식의 기계로서, 미국 코넬 대학의 로젠블랫이 만들었다.'}]
# [샘플 157] [{'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}, {'1_word': '스케줄링', '2_desc': '컴퓨터에서 처리해야 할 작업들의 일정과 진행 방법 따위에 대한 세부 내용을 수립하는 일.'}, {'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 158] [{'1_word': '캠버', '2_desc': '비행기의 날개나 헬리콥터의 로터에서 양력이 잘 발생하도록 볼록하게 만든 위쪽 면의 모양. 에어포일의 윗면이 볼록한 비율이 높을수록 양력 발생에 유리하다.'}]
# [샘플 159] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 160] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 161] [{'1_word': '필렛', '2_desc': '공항의 활주로, 유도로, 계류장으로 연결된 포장 부분에서 폭을 늘린 부분. 항공기의 이착륙과 정비 따위를 원활히 하기 위하여, 항공기가 이 도로를 통과할 때 방향을 쉽게 회전하도록 돕는다. ⇒규범 표기는 미확정이다.'}]
# [샘플 162] [{'1_word': '피투피', '2_desc': '네트워크의 각 노드 또는 피어가 클라이언트와 서버가 될 수 있는 분산 네트워크 구조. 클라이언트나 서버의 개념 없이, 네트워크 노드들이 서로 클라이언트와 서버 역할을 동시에 하게 된다.'}]
# [샘플 163] [{'1_word': '드론', '2_desc': '자율 항법 장치에 의하여 자동 조종되거나 무선 전파를 이용하여 원격 조종되는 무인 비행 물체.'}]
# [샘플 164] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 165] [{'1_word': '제어선', '2_desc': '무인국의 장치 따위를 원거리에 있는 유인국에서 제어하여 예비 장치나 예비 회선으로 전환하기 위한 제어 신호나 장치의 작동 상태를 알기 위한 감시 신호의 전송로.'}]
# [샘플 166] [{'1_word': '수학화', '2_desc': '수학자의 필요에 맞게 적절히 손질하여 본질로 조직해 내는 조직화 활동. 수학자들이 수학적 개념, 아이디어, 구조 등을 포함하는 수학적 수단에 의해 현실의 경험을 조직하거나 수학적 경험을 체계화시켜 나가는 것을 의미한다.'}]
# [샘플 167] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 168] [{'1_word': '디엠엘', '2_desc': '데이터베이스에서 자료를 검색, 추가, 갱신, 삭제하기 위하여 데이터베이스 관리 시스템과 교류하는 데 쓰는 프로그램 언어.'}]
# [샘플 169] [{'1_word': '아이피', '2_desc': '오에스아이 기준 모델의 제3 계층인 망 계층에 해당하는 프로토콜. 경로 제어를 위한 규약으로, 서로 다른 네트워크 간의 데이터 전송을 가능하게 한다.'}]
# [샘플 170] [{'1_word': '대류', '2_desc': '기체나 액체에서, 물질이 이동함으로써 열이 전달되는 현상. 기체나 액체가 부분적으로 가열되면 가열된 부분이 팽창하면서 밀도가 작아져 위로 올라가고, 위에 있던 밀도가 큰 부분은 내려오게 되는데, 이런 과정이 되풀이되면서 기체나 액체의 전체가 고르게 가열된다.'}]
# [샘플 171] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}, {'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 172] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}, {'1_word': '표준 편차', '2_desc': '자료의 분산 정도를 나타내는 수치. 분산의 양의 제곱근으로, 표준 편차가 작은 것은 평균값 주위의 분산의 정도가 작은 것을 나타낸다.'}]
# [샘플 173] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 174] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 175] [{'1_word': '우함수', '2_desc': '<I>x</I>의 함수 <I>f(x)</I>가 <I>f(-x)=f(x)</I>라는 관계를 만족할 때에 <I>f(x)</I>를 이르는 말. 이 함수의 그래프는 <I>y</I>축에 대하여 대칭이다.'}]
# [샘플 176] [{'1_word': '로터', '2_desc': '발전기, 전동기, 터빈, 수차 따위의 회전 기계에서 회전하는 부분을 통틀어 이르는 말.'}]
# [샘플 177] [{'1_word': '무결성', '2_desc': '데이터의 정보가 변경되거나 오염되지 않도록 하는 원칙. 네트워크에서 데이터 전송 시 비인가 접속자가 데이터를 변경하거나 위조하지 않았다는 것을 나타낸다.'}]
# [샘플 178] [{'1_word': '전압', '2_desc': '전기장이나 도체 안에 있는 두 점 사이의 전기적인 위치 에너지 차. 단위는 볼트.'}, {'1_word': '전류', '2_desc': '전력 컨버터에서 한쪽 도통 암에서 다른 쪽 도통 암으로 전류가 끊김 없이 순차적으로 이동하는 현상. 양쪽 암은 유한 시간 구간 동안만 동시에 도통된다.'}]
# [샘플 179] [{'1_word': '스톨', '2_desc': '비행기 주익(主翼)의 양력(揚力)이 급격히 떨어지는 현상. 또는 비행기가 속도를 잃고 그 앞을 위로 든 채 떨어지는 비행 상태. 대부분 양력을 잃어 급속히 기수를 내리고 강하하므로 회복하기까지는 정상으로 조종할 수 없다.'}]
# [샘플 180] [{'1_word': '항공법', '2_desc': '국제 민간 항공 조약의 규정과 그에 딸린 표준과 방식에 따라 항공기의 항행의 안전을 도모하고 항공 운송 사업의 질서를 확립하여 항공의 발달을 꾀하기 위한 법률.'}]
# [샘플 181] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 182] [{'1_word': '에이피아이', '2_desc': '응용 프로그램이 컴퓨터 운영 체계나 데이터베이스 관리 시스템 따위의 다른 프로그램이나 장치의 기능을 이용하기 위한 작용 수단. 컴퓨터 운영 체계의 기능과 그 기능을 사용하는 방법을 정의한 함수의 집합이다.'}]
# [샘플 183] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 184] [{'1_word': '컴파일', '2_desc': '프로그램 제작자가 코볼ㆍ포트란 따위의 고급 언어로 쓰인 프로그램을 번역하고, 컴퓨터에서 실행할 수 있는 기계어 프로그램으로 고치는 과정.'}, {'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 185] [{'1_word': '전처리기', '2_desc': '컴퓨터 처리 작업 시 중심이 되는 처리를 하는 프로그램의 조건에 맞추기 위해 수행하는 사전 처리 프로그램.'}]
# [샘플 186] [{'1_word': '라디안', '2_desc': '원둘레 위에서 반지름의 길이와 같은 길이를 갖는 호에 대응하는 중심각의 크기. 1라디안은 약 57도 17분 44.8초이다. 기호는 rad.'}]
# [샘플 187] [{'1_word': '피보나치', '2_desc': '이탈리아의 수학자(1170~1250?). ≪주판서(珠板書)≫를 지어 아라비아의 산술과 대수학을 유럽에 소개하였으며, ‘피보나치수열’에 이름이 남아 있다.'}]
# [샘플 188] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 189] [{'1_word': '캡션', '2_desc': '삽화, 사진 따위에 붙는 짧은 해설문(解說文).'}]
# [샘플 190] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 191] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 192] [{'1_word': '여집합', '2_desc': '열두 음의 체계에서 하나의 집합에 대해 상호 보충적 관계에 놓이는 다른 집합. 음고류 집합 이론에서 사용되는 용어이다.'}]
# [샘플 193] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 194] [{'1_word': '회전익', '2_desc': '중심축을 중심으로 회전하여 양력이 생기는 날개. 헬리콥터의 날개 따위를 이른다.'}, {'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}]
# [샘플 195] [{'1_word': '원순열', '2_desc': '몇 개의 물건이나 원소의 차례를 바꾸어 원둘레 위에 배열하는 순열. 그 배열 방법의 수는 (n-1)!이다.'}]
# [샘플 196] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 197] [{'1_word': '연산자', '2_desc': '벡터 공간, 함수 공간의 원소를 다른 원소에 대응시키는 변환. 수에 수를 대응시키는 보통의 함수 개념을 확장한 것이다.'}]
# [샘플 198] [{'1_word': '아파치', '2_desc': '고성능의 하이퍼텍스트 전송 규약 서버. ⇒규범 표기는 미확정이다.'}]
# [샘플 199] [{'1_word': '무결성', '2_desc': '데이터의 정보가 변경되거나 오염되지 않도록 하는 원칙. 네트워크에서 데이터 전송 시 비인가 접속자가 데이터를 변경하거나 위조하지 않았다는 것을 나타낸다.'}]
# [샘플 200] [{'1_word': '수학화', '2_desc': '수학자의 필요에 맞게 적절히 손질하여 본질로 조직해 내는 조직화 활동. 수학자들이 수학적 개념, 아이디어, 구조 등을 포함하는 수학적 수단에 의해 현실의 경험을 조직하거나 수학적 경험을 체계화시켜 나가는 것을 의미한다.'}]
# [샘플 201] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 202] [{'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}]
# [샘플 203] [{'1_word': '오에스', '2_desc': '컴퓨터의 하드웨어 시스템을 효율적으로 운영하기 위한 소프트웨어. 컴퓨터를 작동하고 시스템 전체를 감시하며, 처리하여야 할 데이터의 관리와 작업 계획 따위를 조정하는 여러 가지의 프로그램으로 구성되어 있다.'}]
# [샘플 204] [{'1_word': '내적', '2_desc': '주어진 두 개의 벡터 A, B 각각의 길이 |A|, |B|와 두 벡터 사이각의 코사인을 곱한 값. 엄밀하게는 벡터 공간에서 정의되는 영(0) 이상의 값을 가지고, 대칭을 이루며 삼각 부등식을 만족하는 함수를 말한다.'}]
# [샘플 205] [{'1_word': '지피유', '2_desc': '컴퓨터 시스템에서, 그래픽에 관련된 연산을 수행하는 장치. 중앙 처리 장치를 대신하여 그래픽 처리 능력을 최대화할 목적으로 쓰인다.'}]
# [샘플 206] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 207] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 208] [{'1_word': '포인터', '2_desc': '컴퓨터 그래픽스에서, 항목을 선택하기 위한 마우스 같은 위치 결정 장치를 갖고 사용자가 이동시킬 수 있는, 화면에 표시된 기호.'}, {'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 209] [{'1_word': '수학화', '2_desc': '수학자의 필요에 맞게 적절히 손질하여 본질로 조직해 내는 조직화 활동. 수학자들이 수학적 개념, 아이디어, 구조 등을 포함하는 수학적 수단에 의해 현실의 경험을 조직하거나 수학적 경험을 체계화시켜 나가는 것을 의미한다.'}]
# [샘플 210] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 211] [{'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}]
# [샘플 212] [{'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}]
# [샘플 213] [{'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 214] [{'1_word': '사분위수', '2_desc': '통계의 변량을 도수 분포로 정리하였을 때 적은 것으로부터 1/4, 3/4 자리의 변량값.'}]
# [샘플 215] [{'1_word': '인공 신경망', '2_desc': '사람의 두뇌와 비슷한 방식으로 정보를 처리하기 위한 알고리즘. 생물의 신경계와 같은 방식으로 작동하도록, 단순하지만 적응적인 요소들을 대량으로 병렬 연결한 망들의 계층적 조직이다.'}]
# [샘플 216] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 217] [{'1_word': '표본', '2_desc': '여러 통계 자료를 포함하는 집단 속에서 그 일부를 뽑아내어 조사한 결과로써 본디의 집단의 성질을 추측할 수 있는 통계 자료.'}]
# [샘플 218] [{'1_word': '변위', '2_desc': '물체가 위치를 바꿈. 또는 그 물체의 나중 위치와 처음 위치의 차이를 나타내는 벡터양. 크기와 방향을 가진다.'}]
# [샘플 219] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 220] [{'1_word': '캡션', '2_desc': '삽화, 사진 따위에 붙는 짧은 해설문(解說文).'}]
# [샘플 221] [{'1_word': '제트 기류', '2_desc': '대류권의 상부 또는 성층권의 하부에서, 좁은 영역에 거의 수평으로 집중하는 강한 기류. 최대 풍속이 100m/s를 넘는 일도 있다. 북반구의 경우, 겨울에는 북위 30도 부근에 있고 여름에는 45도 부근까지 북상한다.'}]
# [샘플 222] [{'1_word': '적분', '2_desc': '어떤 함수가 주어졌을 때, 미분하면 그 주어진 함수가 되는 함수.'}]
# [샘플 223] [{'1_word': '대류', '2_desc': '기체나 액체에서, 물질이 이동함으로써 열이 전달되는 현상. 기체나 액체가 부분적으로 가열되면 가열된 부분이 팽창하면서 밀도가 작아져 위로 올라가고, 위에 있던 밀도가 큰 부분은 내려오게 되는데, 이런 과정이 되풀이되면서 기체나 액체의 전체가 고르게 가열된다.'}]
# [샘플 224] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}, {'1_word': '파이선', '2_desc': '원시 프로그램을 한 문장 단위로 번역하여 실행할 수 있게 하는 인터프리터 언어. ⇒규범 표기는 미확정이다.'}]
# [샘플 225] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 226] [{'1_word': '선언', '2_desc': '프로그램에서 사용되는 변수에 대하여 프로그램 내에서 속성, 범위 따위를 알려 주는 행위.'}]
# [샘플 227] [{'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 228] [{'1_word': '포인터', '2_desc': '컴퓨터 그래픽스에서, 항목을 선택하기 위한 마우스 같은 위치 결정 장치를 갖고 사용자가 이동시킬 수 있는, 화면에 표시된 기호.'}, {'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}, {'1_word': '배열', '2_desc': '동일한 성격의 데이터를 관리하기 쉽도록 하나로 묶는 일.'}, {'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 229] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 230] [{'1_word': 'PDF', '2_desc': '전자 문서 형식의 하나. 일반 문서 및 문자, 도형, 그림, 글꼴을 화면으로 보거나 탐색하고 다른 사람과 주고받기에 적합하게 만들어졌다.'}]
# [샘플 231] [{'1_word': '배열', '2_desc': '동일한 성격의 데이터를 관리하기 쉽도록 하나로 묶는 일.'}]
# [샘플 232] [{'1_word': '클라우드', '2_desc': '인터넷상에 마련한 개인용 서버에 각종 문서, 사진, 음악 따위의 파일 및 정보를 저장하여 두는 시스템. ⇒규범 표기는 미확정이다.'}]
# [샘플 233] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 234] [{'1_word': '미분', '2_desc': '미분법 및 그에 연관된 이론과 응용을 연구하는 학문.'}]
# [샘플 235] [{'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}, {'1_word': '스케줄링', '2_desc': '컴퓨터에서 처리해야 할 작업들의 일정과 진행 방법 따위에 대한 세부 내용을 수립하는 일.'}]
# [샘플 236] [{'1_word': '파이선', '2_desc': '원시 프로그램을 한 문장 단위로 번역하여 실행할 수 있게 하는 인터프리터 언어. ⇒규범 표기는 미확정이다.'}, {'1_word': '기술 통계', '2_desc': '자료를 조직하고 요약하는 한 방법으로, 실험자로부터 얻은 데이터를 자료의 특성들을 이해하기 쉽게 기술해 주는 수치로 표현하는 방법.'}]
# [샘플 237] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 238] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 239] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 240] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 241] [{'1_word': '파이선', '2_desc': '원시 프로그램을 한 문장 단위로 번역하여 실행할 수 있게 하는 인터프리터 언어. ⇒규범 표기는 미확정이다.'}]
# [샘플 242] [{'1_word': '러더', '2_desc': '비행기의 수직 안정판의 뒷전에 부착되어 있는 조종 면. 조종실의 러더 페달로 조종하며 러더의 작동으로 비행기는 수직축을 중심으로 하여 좌나 우로 선회하게 된다. ⇒규범 표기는 미확정이다.'}]
# [샘플 243] [{'1_word': '프락시', '2_desc': '시스템의 일부 기능을 다른 것이 임시로 대행하는 것. 주 컴퓨터가 다운되었을 때 복구될 때까지 그 기능을 대신하는 시스템이나 컴퓨터의 통신 포트가 부족할 때 쓸 수 있는 임시 포트 따위를 이른다.'}]
# [샘플 244] [{'1_word': '객체 지향 언어', '2_desc': '객체 지향 프로그래밍에서 사용하는 언어. 객체를 생성하고 조작하며 객체끼리 관계를 맺음으로써 여러 객체가 함께 수행될 수 있게 한다.'}]
# [샘플 245] [{'1_word': '샘플링', '2_desc': '통계의 목적으로 모집단에서 표본을 골라내는 일. 임의 추출법, 층화 추출법 따위가 있다.'}]
# [샘플 246] [{'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}, {'1_word': '회전익', '2_desc': '중심축을 중심으로 회전하여 양력이 생기는 날개. 헬리콥터의 날개 따위를 이른다.'}]
# [샘플 247] [{'1_word': '휴리스틱', '2_desc': '의사 결정 과정을 단순화하여 만든 지침. 완벽한 의사 결정을 하려는 것이 아니라 이용 가능한 정보를 활용하여 실현 가능한 결정을 하려는 것이 목적이다. ⇒규범 표기는 미확정이다.'}]
# [샘플 248] [{'1_word': '모듈', '2_desc': '프로그램을 기능별로 분할한 논리적인 일부분.'}]
# [샘플 249] [{'1_word': '계기 비행', '2_desc': '어둠이나 안개 따위로 앞이 보이지 아니하는 항로를 계기에 의존하여 비행하는 일.'}]
# [샘플 250] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 251] [{'1_word': '비밀 키', '2_desc': '한 개체의 비대칭 키 쌍 중에서 그 개체만이 사용하는 비공개 키. 비밀 메시지를 교환하는 상대끼리만 아는 암호 키이므로 어느 한쪽이 키를 분실하면 시스템에 위험이 초래되는 단점이 있기 때문에 비밀 키와 공개 키를 조합해서 사용하기도 한다.'}]
# [샘플 252] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 253] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 254] [{'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 255] [{'1_word': '문자열', '2_desc': '데이터로 다루는 일련의 문자. 숫자를 포함하는 것이어도 계산하는 숫자로서가 아니라 코드의 일부로 쓰는 것이면 문자열이라 할 수 있다.'}]
# [샘플 256] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 257] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 258] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 259] [{'1_word': '스케줄링', '2_desc': '컴퓨터에서 처리해야 할 작업들의 일정과 진행 방법 따위에 대한 세부 내용을 수립하는 일.'}]
# [샘플 260] [{'1_word': '선회', '2_desc': '항공기가 곡선을 그리듯 진로를 바꿈.'}]
# [샘플 261] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 262] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 263] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 264] [{'1_word': '하층운', '2_desc': '지상 2km 이내의 공중에 있는 구름. 층적운, 층운 따위가 있다.'}]
# [샘플 265] [{'1_word': '러더', '2_desc': '비행기의 수직 안정판의 뒷전에 부착되어 있는 조종 면. 조종실의 러더 페달로 조종하며 러더의 작동으로 비행기는 수직축을 중심으로 하여 좌나 우로 선회하게 된다. ⇒규범 표기는 미확정이다.'}]
# [샘플 266] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 267] [{'1_word': '디엠이', '2_desc': '일종의 이차 레이다로 항공기가 질문 펄스(pulse) 전파를 발사한 뒤 지상국의 응답 펄스 전파를 수신하기까지의 시간을 측정하여 거리를 환산하여 내는 장치.'}]
# [샘플 268] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 269] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 270] [{'1_word': '오에스', '2_desc': '컴퓨터의 하드웨어 시스템을 효율적으로 운영하기 위한 소프트웨어. 컴퓨터를 작동하고 시스템 전체를 감시하며, 처리하여야 할 데이터의 관리와 작업 계획 따위를 조정하는 여러 가지의 프로그램으로 구성되어 있다.'}]
# [샘플 271] [{'1_word': '매개 변수', '2_desc': '두 개 이상의 변수 사이의 함수 관계를 간접적으로 표시할 때 사용하는 변수.'}]
# [샘플 272] [{'1_word': '화용론', '2_desc': '말하는 이, 듣는 이, 시간, 장소 따위로 구성되는 맥락과 관련하여 문장의 의미를 체계적으로 분석하려는 의미론의 한 분야.'}]
# [샘플 273] [{'1_word': '뉴런', '2_desc': '신경 계통의 구조적ㆍ기능적 단위. 하나의 세포체와 그 돌기인 가지 돌기와 신경 돌기로 구성된다. 중추 신경 계통에서는 회백질에 모여 있고, 말초 신경 계통에서는 신경절에 집합해 있다.'}, {'1_word': '퍼셉트론', '2_desc': '시각과 뇌의 기능을 모델화한 학습 기계. 학습 기능과 지적 동작 기능을 가진 패턴 인식의 기계로서, 미국 코넬 대학의 로젠블랫이 만들었다.'}]
# [샘플 274] [{'1_word': '샘플링', '2_desc': '통계의 목적으로 모집단에서 표본을 골라내는 일. 임의 추출법, 층화 추출법 따위가 있다.'}]
# [샘플 275] [{'1_word': '헤딩', '2_desc': '기수(機首)가 향하고 있는 실제 방향. 일반적으로 북쪽을 기준으로 하여 항공기의 세로축이 가리키는 방향을 이른다.'}]
# [샘플 276] [{'1_word': '뉴런', '2_desc': '신경 계통의 구조적ㆍ기능적 단위. 하나의 세포체와 그 돌기인 가지 돌기와 신경 돌기로 구성된다. 중추 신경 계통에서는 회백질에 모여 있고, 말초 신경 계통에서는 신경절에 집합해 있다.'}]
# [샘플 277] [{'1_word': '행렬', '2_desc': '여러 숫자나 문자를 정사각형 또는 직사각형으로 배열한 것. 배열한 숫자나 문자를 그 행렬의 성분 또는 원소라고 하고, 가로로 배열된 원소를 행, 세로로 배열된 원소를 열이라고 한다.'}]
# [샘플 278] [{'1_word': '극점', '2_desc': '구(球)에 그린 원의 중심을 지나고, 이 원이 그리는 평면에 수직인 구의 지름의 양 끝을 이르는 말.'}]
# [샘플 279] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 280] [{'1_word': '배열', '2_desc': '동일한 성격의 데이터를 관리하기 쉽도록 하나로 묶는 일.'}]
# [샘플 281] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 282] [{'1_word': '메시', '2_desc': '컴퓨터 그래픽에서 그물망과 같이 일정한 간격으로 빈 공간이 있는 형태의 입체 도형.'}]
# [샘플 283] [{'1_word': '에스큐엘', '2_desc': '데이터베이스에서 정보를 얻거나 갱신하기 위해 표준 대화식으로 구성된 프로그래밍 언어. 관계형 데이터베이스 관리 시스템에서의 자료 검색과 관리, 데이터베이스 관리 시스템에서 데이터 구조와 표현 기술을 수용하는 데이터베이스 스키마 파일의 생성과 수정, 데이터베이스 객체의 접근 조정 관리를 위해 고안되었다. 대다수의 데이터베이스 관련 프로그램들이 이 언어를 표준으로 채택하고 있다.'}]
# [샘플 284] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 285] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 286] [{'1_word': '엘리자', '2_desc': '사람과 컴퓨터가 대화를 할 수 있도록 리스프를 사용하여 만들어진 프로그램. 사람이 하나의 문장을 입력하면, 컴퓨터는 사람이 입력한 문장에 나타나는 키워드를 이용하여 질문을 하고, 사람은 다시 이 질문에 대답을 하게 된다. ⇒규범 표기는 미확정이다.'}]
# [샘플 287] [{'1_word': '아이피', '2_desc': '오에스아이 기준 모델의 제3 계층인 망 계층에 해당하는 프로토콜. 경로 제어를 위한 규약으로, 서로 다른 네트워크 간의 데이터 전송을 가능하게 한다.'}]
# [샘플 288] [{'1_word': '오에스', '2_desc': '컴퓨터의 하드웨어 시스템을 효율적으로 운영하기 위한 소프트웨어. 컴퓨터를 작동하고 시스템 전체를 감시하며, 처리하여야 할 데이터의 관리와 작업 계획 따위를 조정하는 여러 가지의 프로그램으로 구성되어 있다.'}]
# [샘플 289] [{'1_word': '우함수', '2_desc': '<I>x</I>의 함수 <I>f(x)</I>가 <I>f(-x)=f(x)</I>라는 관계를 만족할 때에 <I>f(x)</I>를 이르는 말. 이 함수의 그래프는 <I>y</I>축에 대하여 대칭이다.'}]
# [샘플 290] [{'1_word': '무결성', '2_desc': '데이터의 정보가 변경되거나 오염되지 않도록 하는 원칙. 네트워크에서 데이터 전송 시 비인가 접속자가 데이터를 변경하거나 위조하지 않았다는 것을 나타낸다.'}]
# [샘플 291] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 292] [{'1_word': '드론', '2_desc': '자율 항법 장치에 의하여 자동 조종되거나 무선 전파를 이용하여 원격 조종되는 무인 비행 물체.'}]
# [샘플 293] [{'1_word': '문자열', '2_desc': '데이터로 다루는 일련의 문자. 숫자를 포함하는 것이어도 계산하는 숫자로서가 아니라 코드의 일부로 쓰는 것이면 문자열이라 할 수 있다.'}]
# [샘플 294] [{'1_word': '선형 회귀', '2_desc': '독립 변수의 일차식으로 된 회귀.'}]
# [샘플 295] [{'1_word': '명령어', '2_desc': '컴퓨터에 연산이나 일정한 동작을 명령하는 기계어.'}]
# [샘플 296] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 297] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 298] [{'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 299] [{'1_word': '사물 인터넷', '2_desc': '사물에 센서와 프로세서를 장착하여 정보를 수집하고 제어ㆍ관리할 수 있도록 인터넷으로 연결되어 있는 시스템.'}]
# [샘플 300] [{'1_word': '제어선', '2_desc': '무인국의 장치 따위를 원거리에 있는 유인국에서 제어하여 예비 장치나 예비 회선으로 전환하기 위한 제어 신호나 장치의 작동 상태를 알기 위한 감시 신호의 전송로.'}]
# [샘플 301] [{'1_word': '선회', '2_desc': '항공기가 곡선을 그리듯 진로를 바꿈.'}]
# [샘플 302] [{'1_word': '무결성', '2_desc': '데이터의 정보가 변경되거나 오염되지 않도록 하는 원칙. 네트워크에서 데이터 전송 시 비인가 접속자가 데이터를 변경하거나 위조하지 않았다는 것을 나타낸다.'}]
# [샘플 303] [{'1_word': '클라우드', '2_desc': '인터넷상에 마련한 개인용 서버에 각종 문서, 사진, 음악 따위의 파일 및 정보를 저장하여 두는 시스템. ⇒규범 표기는 미확정이다.'}]
# [샘플 304] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 305] [{'1_word': '행렬', '2_desc': '여러 숫자나 문자를 정사각형 또는 직사각형으로 배열한 것. 배열한 숫자나 문자를 그 행렬의 성분 또는 원소라고 하고, 가로로 배열된 원소를 행, 세로로 배열된 원소를 열이라고 한다.'}]
# [샘플 306] [{'1_word': '명령어', '2_desc': '컴퓨터에 연산이나 일정한 동작을 명령하는 기계어.'}]
# [샘플 307] [{'1_word': '비밀 키', '2_desc': '한 개체의 비대칭 키 쌍 중에서 그 개체만이 사용하는 비공개 키. 비밀 메시지를 교환하는 상대끼리만 아는 암호 키이므로 어느 한쪽이 키를 분실하면 시스템에 위험이 초래되는 단점이 있기 때문에 비밀 키와 공개 키를 조합해서 사용하기도 한다.'}]
# [샘플 308] [{'1_word': '표본', '2_desc': '여러 통계 자료를 포함하는 집단 속에서 그 일부를 뽑아내어 조사한 결과로써 본디의 집단의 성질을 추측할 수 있는 통계 자료.'}]
# [샘플 309] [{'1_word': '클라우드', '2_desc': '인터넷상에 마련한 개인용 서버에 각종 문서, 사진, 음악 따위의 파일 및 정보를 저장하여 두는 시스템. ⇒규범 표기는 미확정이다.'}]
# [샘플 310] [{'1_word': '포인터', '2_desc': '컴퓨터 그래픽스에서, 항목을 선택하기 위한 마우스 같은 위치 결정 장치를 갖고 사용자가 이동시킬 수 있는, 화면에 표시된 기호.'}]
# [샘플 311] [{'1_word': '스로틀', '2_desc': '통로의 면적을 여러 가지로 변화시켜 흐르는 유체(流體)를 제한하는 판(瓣). 특히 내연 기관의 기화기에 붙어 흡입 공기량을 조절하는 것이나 증기 기관에 붙어 증기량을 조절하는 것을 이른다.'}]
# [샘플 312] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 313] [{'1_word': '오에스', '2_desc': '컴퓨터의 하드웨어 시스템을 효율적으로 운영하기 위한 소프트웨어. 컴퓨터를 작동하고 시스템 전체를 감시하며, 처리하여야 할 데이터의 관리와 작업 계획 따위를 조정하는 여러 가지의 프로그램으로 구성되어 있다.'}]
# [샘플 314] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 315] [{'1_word': '스톨', '2_desc': '비행기 주익(主翼)의 양력(揚力)이 급격히 떨어지는 현상. 또는 비행기가 속도를 잃고 그 앞을 위로 든 채 떨어지는 비행 상태. 대부분 양력을 잃어 급속히 기수를 내리고 강하하므로 회복하기까지는 정상으로 조종할 수 없다.'}]
# [샘플 316] [{'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}]
# [샘플 317] [{'1_word': '명령어', '2_desc': '컴퓨터에 연산이나 일정한 동작을 명령하는 기계어.'}]
# [샘플 318] [{'1_word': '스레드', '2_desc': '다중 작업 환경에서 운영 체제가 여러 프로그램을 병행하여 처리할 때 효율적인 처리를 위하여 분할한 처리 단위.'}, {'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}, {'1_word': '레지스터', '2_desc': '특정한 목적으로 외부 정보를 일시적으로 기억하는 장치. 데이터를 읽고 쓰는 기능이 매우 빠르며, 중앙 처리 장치 안에 사용된다.'}]
# [샘플 319] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 320] [{'1_word': '항공법', '2_desc': '국제 민간 항공 조약의 규정과 그에 딸린 표준과 방식에 따라 항공기의 항행의 안전을 도모하고 항공 운송 사업의 질서를 확립하여 항공의 발달을 꾀하기 위한 법률.'}]
# [샘플 321] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 322] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 323] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 324] [{'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 325] [{'1_word': '메시', '2_desc': '컴퓨터 그래픽에서 그물망과 같이 일정한 간격으로 빈 공간이 있는 형태의 입체 도형.'}]
# [샘플 326] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 327] [{'1_word': '표준 편차', '2_desc': '자료의 분산 정도를 나타내는 수치. 분산의 양의 제곱근으로, 표준 편차가 작은 것은 평균값 주위의 분산의 정도가 작은 것을 나타낸다.'}, {'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 328] [{'1_word': '백도어', '2_desc': '시스템이 고장 났을 경우에 시스템을 만든 회사의 프로그래머가 직접 접속해서 점검할 수 있도록 특정 계정을 열어 놓는 일. ⇒규범 표기는 미확정이다.'}]
# [샘플 329] [{'1_word': '뷰', '2_desc': '컴퓨터 그래픽스에서 3차원 객체의 가능한 표현 가운데 하나.'}]
# [샘플 330] [{'1_word': '파이선', '2_desc': '원시 프로그램을 한 문장 단위로 번역하여 실행할 수 있게 하는 인터프리터 언어. ⇒규범 표기는 미확정이다.'}]
# [샘플 331] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 332] [{'1_word': '뷰', '2_desc': '컴퓨터 그래픽스에서 3차원 객체의 가능한 표현 가운데 하나.'}]
# [샘플 333] [{'1_word': '항공법', '2_desc': '국제 민간 항공 조약의 규정과 그에 딸린 표준과 방식에 따라 항공기의 항행의 안전을 도모하고 항공 운송 사업의 질서를 확립하여 항공의 발달을 꾀하기 위한 법률.'}]
# [샘플 334] [{'1_word': '교집합', '2_desc': '두 집합 A와 B가 있을 때 집합 A, B에 공통으로 속하는 원소 전체로 이루어진 집합. ‘A∩B’로 나타낸다.'}]
# [샘플 335] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 336] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 337] [{'1_word': '레지스터', '2_desc': '특정한 목적으로 외부 정보를 일시적으로 기억하는 장치. 데이터를 읽고 쓰는 기능이 매우 빠르며, 중앙 처리 장치 안에 사용된다.'}, {'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 338] [{'1_word': '리니어', '2_desc': '시스템의 입출력 관계에서 입력에 직선적으로 비례하여 출력이 발생하는 모양.'}]
# [샘플 339] [{'1_word': '컴파일', '2_desc': '프로그램 제작자가 코볼ㆍ포트란 따위의 고급 언어로 쓰인 프로그램을 번역하고, 컴퓨터에서 실행할 수 있는 기계어 프로그램으로 고치는 과정.'}]
# [샘플 340] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 341] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 342] [{'1_word': '퍼셉트론', '2_desc': '시각과 뇌의 기능을 모델화한 학습 기계. 학습 기능과 지적 동작 기능을 가진 패턴 인식의 기계로서, 미국 코넬 대학의 로젠블랫이 만들었다.'}]
# [샘플 343] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 344] [{'1_word': '미적분학', '2_desc': '미분학과 적분학을 아울러 이르는 말.'}]
# [샘플 345] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 346] [{'1_word': '아이피', '2_desc': '오에스아이 기준 모델의 제3 계층인 망 계층에 해당하는 프로토콜. 경로 제어를 위한 규약으로, 서로 다른 네트워크 간의 데이터 전송을 가능하게 한다.'}]
# [샘플 347] [{'1_word': '전압', '2_desc': '전기장이나 도체 안에 있는 두 점 사이의 전기적인 위치 에너지 차. 단위는 볼트.'}]
# [샘플 348] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]
# [샘플 349] [{'1_word': '아이아타', '2_desc': '1944년 시카고에서 채택되어, 1945년 발효된 국제 항공 협정. 국가 간의 상공 통과의 자유, 기술 착륙의 자유 따위를 인정하였다. 백여 국이 가입하였으며 우리나라는 1960년에 가입하였다.'}]
# [샘플 350] [{'1_word': '배열', '2_desc': '동일한 성격의 데이터를 관리하기 쉽도록 하나로 묶는 일.'}]
# [샘플 351] [{'1_word': '라디안', '2_desc': '원둘레 위에서 반지름의 길이와 같은 길이를 갖는 호에 대응하는 중심각의 크기. 1라디안은 약 57도 17분 44.8초이다. 기호는 rad.'}]
# [샘플 352] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 353] [{'1_word': '공개 키', '2_desc': '시스템 암호화에서, 지정된 인증 기관으로부터 제공하는 키. 이로부터 개인 키가 생성되며, 사용자가 시스템에 접근할 때 개인 키와 결합하여 인증 여부를 확인하는 데 사용한다.'}]
# [샘플 354] [{'1_word': '레이드', '2_desc': '일부 중복된 데이터를 여러 개의 하드 디스크에 나눠서 저장하는 기술. 데이터를 나누는 다양한 방법이 존재하며 이 방법들을 레벨이라 하는데, 레벨에 따라 저장 장치의 신뢰성을 높여 전체적인 성능을 향상시킬 수 있다. ⇒규범 표기는 미확정이다.'}]
# [샘플 355] [{'1_word': '클라우드', '2_desc': '인터넷상에 마련한 개인용 서버에 각종 문서, 사진, 음악 따위의 파일 및 정보를 저장하여 두는 시스템. ⇒규범 표기는 미확정이다.'}]
# [샘플 356] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 357] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 358] [{'1_word': '자바스크립트', '2_desc': '주로 웹 페이지에서 동작을 나타낼 때 사용되는 프로그래밍 언어. 자바와는 다른 언어로, 웹 문서 제작에 많이 사용된다.'}]
# [샘플 359] [{'1_word': '컴파일러', '2_desc': '고급 언어로 작성된 원시 프로그램을 입력으로 받아 기계어로 된 목적 프로그램을 출력하기 위하여 사용하는 언어 번역 프로그램.'}]
# [샘플 360] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 361] [{'1_word': '고정익', '2_desc': '항공기의 동체(胴體)에 고정된 날개. 헬리콥터 따위의 회전 날개에 대하여 주로 양력(揚力)을 얻기 위한 보통 비행기의 날개를 이른다.'}]
# [샘플 362] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 363] [{'1_word': '불릿', '2_desc': '여러 가지 목록을 열거히는 경우에 각각의 목록 앞에 사용되는 가운뎃점. ⇒규범 표기는 미확정이다.'}]
# [샘플 364] [{'1_word': '인공 지능', '2_desc': '인간의 지능이 가지는 학습, 추리, 적응, 논증 따위의 기능을 갖춘 컴퓨터 시스템. 전문가 시스템, 자연 언어의 이해, 음성 번역, 로봇 공학, 인공 시각, 문제 해결, 학습과 지식 획득, 인지 과학 따위에 응용한다.'}]
# [샘플 365] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 366] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 367] [{'1_word': '저작권', '2_desc': '문학, 예술, 학술에 속하는 창작물에 대하여 저작자나 그 권리 승계인이 행사하는 배타적ㆍ독점적 권리. 저작자의 생존 기간 및 사후 70년간 유지된다.'}]
# [샘플 368] [{'1_word': '배열', '2_desc': '동일한 성격의 데이터를 관리하기 쉽도록 하나로 묶는 일.'}]
# [샘플 369] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 370] [{'1_word': '캡션', '2_desc': '삽화, 사진 따위에 붙는 짧은 해설문(解說文).'}]
# [샘플 371] [{'1_word': '디디엘', '2_desc': '데이터베이스 관리자와 시스템 프로그래머가 구축하고자 하는 데이터의 논리적ㆍ물리적 구조를 기술하는 언어. 데이터 항목, 레코드, 세그먼트, 파일 형식, 파일 이름, 키 항목, 세그먼트 간의 관계, 링크 이름, 데이터 항목의 형과 값의 범위, 파일에 저장할 수 있는 최대 레코드 수, 보안 방법, 액세스 방법 따위를 규정한다.'}]
# [샘플 372] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 373] [{'1_word': '공역', '2_desc': '비행 중인 항공기가 충돌하는 것을 막기 위하여 반드시 필요한 공간. 또는 연습할 때 비행기 편대가 차지하는 공간.'}]
# [샘플 374] [{'1_word': '노탐', '2_desc': '항공기의 안전 운항을 위하여 관계 기관이 승무원에게 제공하는 여러 가지 정보. 항공ㆍ운항 업무 및 군사 연습 따위의 정보가 제공된다.'}, {'1_word': '에이티아이에스', '2_desc': '교통 정보 시스템의 하나. 특히 도로 교통과 관련되어 있다. 내비게이션따위의 매체를 통해 정보를 제공함으로써 운전자가 목적지까지 경로를 정하고 조정할 수 있도록 도와준다.'}]
# [샘플 375] [{'1_word': '스크립트', '2_desc': '소프트웨어를 실행할 수 있는, 프로그램 언어 이외의 간단한 언어로 작성한 명령어.'}]
# [샘플 376] [{'1_word': '프로세스', '2_desc': '컬러 원고를 사진 제판이나 컬러 스캐너로 색 분해를 한 다음 다색 인쇄용의 평판을 만드는 일. 또는 그렇게 만든 판.'}]
# [샘플 377] [{'1_word': '스레드', '2_desc': '다중 작업 환경에서 운영 체제가 여러 프로그램을 병행하여 처리할 때 효율적인 처리를 위하여 분할한 처리 단위.'}]
# [샘플 378] [{'1_word': '메모리', '2_desc': '데이터나 명령을 비롯하여 컴퓨터 내부에서 계산 처리 한 결과를 기억하는 장치. 주기억 장치와 보조 기억 장치로 나눈다.'}]
# [샘플 379] [{'1_word': '루프', '2_desc': '조건이 만족될 때까지 반복하여 실행할 수 있는 명령의 집합.'}]
# [샘플 380] [{'1_word': '무결성', '2_desc': '데이터의 정보가 변경되거나 오염되지 않도록 하는 원칙. 네트워크에서 데이터 전송 시 비인가 접속자가 데이터를 변경하거나 위조하지 않았다는 것을 나타낸다.'}]
# [샘플 381] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 382] [{'1_word': '미분', '2_desc': '어떤 함수의 미분 계수를 구하는 일.'}]
# [샘플 383] [{'1_word': '클라우드', '2_desc': '인터넷상에 마련한 개인용 서버에 각종 문서, 사진, 음악 따위의 파일 및 정보를 저장하여 두는 시스템. ⇒규범 표기는 미확정이다.'}]
# [샘플 384] [{'1_word': '뉴런', '2_desc': '신경 계통의 구조적ㆍ기능적 단위. 하나의 세포체와 그 돌기인 가지 돌기와 신경 돌기로 구성된다. 중추 신경 계통에서는 회백질에 모여 있고, 말초 신경 계통에서는 신경절에 집합해 있다.'}]
# [샘플 385] [{'1_word': '변수', '2_desc': '프로그램 언어에 있어서 다른 값을 가질 수 있지만 어떤 시점에는 한 개의 값만을 갖는 언어 대상물.'}]
# [샘플 386] [{'1_word': '행렬', '2_desc': '여러 숫자나 문자를 정사각형 또는 직사각형으로 배열한 것. 배열한 숫자나 문자를 그 행렬의 성분 또는 원소라고 하고, 가로로 배열된 원소를 행, 세로로 배열된 원소를 열이라고 한다.'}]
# [샘플 387] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 388] [{'1_word': '패킷', '2_desc': '데이터 전송에서 사용되는 데이터의 묶음. 패킷 전송은 두 지점 사이에 데이터를 연속적으로 전송하지 않고, 전송할 데이터를 적당한 크기로 나누어 패킷의 형태로 구성한 다음 패킷들을 하나씩 보내는 방법을 쓴다. 각각의 패킷은 일정한 크기의 데이터뿐만 아니라 데이터 수신처, 주소 또는 제어 부호 따위의 제어 정보까지 담고 있다. 보통 한 패킷은 1,024비트 데이터를 담을 수 있다.'}]
# [샘플 389] [{'1_word': '문자열', '2_desc': '데이터로 다루는 일련의 문자. 숫자를 포함하는 것이어도 계산하는 숫자로서가 아니라 코드의 일부로 쓰는 것이면 문자열이라 할 수 있다.'}]
# [샘플 390] [{'1_word': '디디엘', '2_desc': '데이터베이스 관리자와 시스템 프로그래머가 구축하고자 하는 데이터의 논리적ㆍ물리적 구조를 기술하는 언어. 데이터 항목, 레코드, 세그먼트, 파일 형식, 파일 이름, 키 항목, 세그먼트 간의 관계, 링크 이름, 데이터 항목의 형과 값의 범위, 파일에 저장할 수 있는 최대 레코드 수, 보안 방법, 액세스 방법 따위를 규정한다.'}]
# [샘플 391] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 392] [{'1_word': '티시피', '2_desc': '오에스아이 기본 참조 모델의 전송 계층에 해당되는 프로토콜. 패킷의 도착 순서대로 오류 수정 따위를 실행한다.'}]
# [샘플 393] [{'1_word': '원순열', '2_desc': '몇 개의 물건이나 원소의 차례를 바꾸어 원둘레 위에 배열하는 순열. 그 배열 방법의 수는 (n-1)!이다.'}]
# [샘플 394] [{'1_word': '인스턴스', '2_desc': '추상적으로 정의된 개념에 대하여 실체적인 값이나 개체를 형성하는 것을 이르는 말.'}]
# [샘플 395] [{'1_word': '연속 함수', '2_desc': '정의구역의 모든 점에서 연속인 함수.'}]
# [샘플 396] [{'1_word': '프로그래밍', '2_desc': '컴퓨터 프로그램을 작성하는 일. 일반적으로는 프로그램 작성 방법의 결정, 코딩(coding), 에러 수정 따위의 작업을 이르지만 특수하게 코딩만을 이를 때도 있다.'}]
# [샘플 397] [{'1_word': '평균', '2_desc': '여러 수나 같은 종류의 양의 중간값을 갖는 수. 산술 평균, 기하 평균, 조화 평균 따위가 있는데 일반적으로 산술 평균을 이른다.'}]

# %%
# "06_transcription"의 "1_text"에서 "2_entity" 데이터를 찾아 (어금부호)로 감싸기 - 이 코드를 실행하면 "06_transcription"의 "1_text"에서 "2_entity"의 "1_word"에 해당하는 단어를 자동으로 (어금부호)로 감싸는 전처리가 진행됨
'''
왜 하느냐?
- 주요 개체들은 전문 용어(수학, 과학, 공학, 프로그래밍 등) 및 일반적인 개념어로 구성됨
- “06_transcription”의 전사 데이터에서 해당 용어가 등장할 가능성이 높음
'''
import os
import json
import re

# JSON 데이터 경로 (기존 디렉토리 유지)
data_dirs = [
    "/data/seungmin/training/labels/eng/arch/",
    "/data/seungmin/training/labels/eng/comp/",
    "/data/seungmin/training/labels/eng/elec/",
    "/data/seungmin/validation/labels/eng/arch/",
    "/data/seungmin/validation/labels/eng/comp/",
    "/data/seungmin/validation/labels/eng/elec/"
]

def apply_entity_tagging(text, entities):
    """
    주어진 텍스트에서 "2_entity" 정보에 해당하는 단어를 `(어금부호)`로 감싸 태깅.
    이미 태깅된 단어가 있는 경우 중복 태깅 방지.
    
    :param text: 원본 텍스트
    :param entities: "2_entity" 리스트 (각 개체의 '1_word' 포함)
    :return: 태깅된 텍스트
    """
    if not entities:
        return text  # entity가 없는 경우 원본 유지

    for entity in entities:
        word = entity["1_word"]
        
        # 이미 `(어금부호)`가 있는 경우 건너뛰기
        if re.search(rf"`{re.escape(word)}`", text):  
            continue
        
        # 태깅 적용
        text = text.replace(word, f"`{word}`")  

    return text

# JSON 파일 처리 (기존 위치에서 업데이트)
for data_dir in data_dirs:
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".json") and not file.startswith("._"):
                json_path = os.path.join(root, file)
                
                try:
                    with open(json_path, "r", encoding="utf-8") as f:
                        data = json.load(f)

                    # "06_transcription" 안에 "1_text"와 "2_entity"가 존재하면 태깅 적용
                    if "06_transcription" in data and "1_text" in data["06_transcription"]:
                        text = data["06_transcription"]["1_text"]
                        entities = data["06_transcription"].get("2_entity", [])

                        # 개체명 태깅 적용
                        processed_text = apply_entity_tagging(text, entities)

                        # 변환된 텍스트 적용
                        data["06_transcription"]["1_text"] = processed_text

                        # 기존 경로에 덮어쓰기 (업데이트)
                        with open(json_path, "w", encoding="utf-8") as f:
                            json.dump(data, f, ensure_ascii=False, indent=4)

                except Exception as e:
                    print(f"@@ 오류 발생: {json_path} (오류: {e})")

print(" @@@기존 JSON 파일 업데이트 완료! (중복 태깅 방지 적용)")
# Out:
#  @@@기존 JSON 파일 업데이트 완료! (중복 태깅 방지 적용)

# %%
# 샘플 확인

import random


# 샘플 확인할 JSON 파일 목록 가져오기
sample_files = []
for data_dir in data_dirs:
    for root, _, files in os.walk(data_dir):
        json_files = [os.path.join(root, f) for f in files if f.endswith(".json") and not f.startswith("._")]
        sample_files.extend(json_files)

# 5개 랜덤 선택
sample_files = random.sample(sample_files, 5)

# 업데이트된 JSON 내용 확인
for file_path in sample_files:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    print(f"파일: {file_path}")
    print(f"개체명 태깅 적용 후: {data['06_transcription']['1_text']}")
    print("-" * 50)
# Out:
# 파일: /data/seungmin/training/labels/eng/elec/C04036/U00231.json
# 개체명 태깅 적용 후: 이러한 기여분에 의한 `방사선` 축적 효과를 반영하기 위하여 인자를 축적 인자 빌드 업 팩터라고 하는데 이 인자는 차폐체의 두께 선 감수개수에 의해 결정되는 보정 인자로 실제 `방사선` 세기의 i는 빌드 업 팩터를 고려해 준 이와 같은 이와 같이 놓고 계산해 줘야 됩니다.
# --------------------------------------------------
# 파일: /data/seungmin/training/labels/eng/elec/C02447/U00272.json
# 개체명 태깅 적용 후: 그래서 이러한 그 (self bag drop)/(셀프 백 드랍) 시스템이 에 굉장히 처리를 하는 그 용량을 확대해줬다라고 할 수가 있는 거죠.
# --------------------------------------------------
# 파일: /data/seungmin/validation/labels/eng/arch/C02861/U00013.json
# 개체명 태깅 적용 후: 자 오늘은 이제 9주차 강의를 말씀을 드릴 텐데요.
# --------------------------------------------------
# 파일: /data/seungmin/training/labels/eng/comp/C13052/U00081.json
# 개체명 태깅 적용 후: 쓰셔도 되는데 그래도 뭐 시기별로 어떤 게 더 필요 어떤 게 더 혁신적인지는 뭐 주관적인 판단이니까 그래도 제가 강의 때 설명드렸던 예제의 중심으로는 알고 계시는 게 좋을 것 같애요.
# --------------------------------------------------
# 파일: /data/seungmin/training/labels/eng/elec/C02879/U00026.json
# 개체명 태깅 적용 후: 근데 과제 너무 부담 갖지 말고 그렇게 어려운 거 아니고 수업하는 거 그 날 수업했던 거 이거 켜놓고 (roll)/(롤)을 한다든지 (battle ground)/(배틀그라운드)나 이런 게임만 하지 않는다면 수업을 그냥 열심히 들었다면 그렇게 오래 안 합니다.
# --------------------------------------------------

# %%
#  “06_transcription” 내에서 "1_text"와 "2_desc"가 함께 존재하는 JSON 파일 찾기
import os
import json
import random

# JSON 데이터 경로
data_dirs = [
    "/data/seungmin/training/labels/eng/arch/",
    "/data/seungmin/training/labels/eng/comp/",
    "/data/seungmin/training/labels/eng/elec/",
    "/data/seungmin/validation/labels/eng/arch/",
    "/data/seungmin/validation/labels/eng/comp/",
    "/data/seungmin/validation/labels/eng/elec/"
]

# "06_transcription"에서 "1_text"와 "2_2_entitydesc"가 같이 있는 파일 찾기
matching_files = []

for data_dir in data_dirs:
    for root, _, files in os.walk(data_dir):
        for file in files:
            if file.endswith(".json") and not file.startswith("._"):
                json_path = os.path.join(root, file)
                
                try:
                    with open(json_path, "r", encoding="utf-8") as f:
                        data = json.load(f)

                    # "06_transcription" 내 "1_text"와 "2_entity"가 있는 경우 찾기
                    if "06_transcription" in data and "1_text" in data["06_transcription"] and "2_entity" in data["06_transcription"]:
                        matching_files.append(json_path)

                        # 5개만 찾으면 중단
                        if len(matching_files) >= 5:
                            break

                except Exception as e:
                    print(f"@@ 오류 발생: {json_path} (오류: {e})")

# 샘플 출력
print(" '1_text'와 '2_entity'가 함께 있는 JSON 파일 샘플:")
for file_path in matching_files:
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    print(f"\n파일: {file_path}")
    print(f"1_text: {data['06_transcription']['1_text']}")
    print(f"2_entity: {data['06_transcription']['2_entity']}")
    print("-" * 50)
# Out:
# 🔍 '1_text'와 '2_desc'가 함께 있는 JSON 파일 샘플:
